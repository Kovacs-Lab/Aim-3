# %%
install.packages("ggplot2")
library("ggplot2")
# Out:
# Installing package into 'C:/Users/daeda/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpuO4Ikp\downloaded_packages

# %%
df <- read.csv("MDS_PC.csv")
df
# Out:
#     Taxa                           PC1           PC2           PC3
# 1   588160__vDNAfen551A01_B01      -0.2566654700 -3.401225e-03 -0.008917734
# 2   588160__vDNAfen551A01_C01      -0.2524576000 -1.734353e-03 -0.006648209
# 3   588160__vDNAfen552A02_B02      -0.2531729300 -8.939717e-03 -0.006620481
# 4   588160__vDNAfen552A02_C02      -0.2462957700 -4.823957e-03 -0.013256828
# 5   588160__vDNAlon094H10_G10      -0.2479192900 -6.217327e-03 -0.001214039
# 6   588160__vDNAlon501A05_B05      -0.2325596700 -1.583474e-02 -0.031021154
# 7   588160__vDNAlon501A05_C05      -0.2382166400 -1.095392e-02 -0.020350127
# 8   588160__vDNAlon787A12_C06       0.0151391765 -1.240191e-01 -0.051012035
# 9   588160__vDNAlon787A12_E08      -0.2468822300 -1.254566e-02 -0.016994223
# 10  588271__vDNAfen551A01_D01       0.2534419600  7.329332e-03  0.018235793
# 11  588271__vDNAfen551A01_E01       0.2517599500  5.508974e-03  0.015563690
# ...

# %%
ggplot(data = df, aes(x = PC1, y = PC2)) +
    geom_point()
# Out:
# plot without title
