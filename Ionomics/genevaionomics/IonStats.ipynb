# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = np.genfromtxt('New_ionStats.csv',delimiter = ',')
data = pd.DataFrame(data)
plt.rcParams['figure.figsize'] = (20,10)

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[3]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("B11",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# 0.2642479
# Mean:  -0.062252392535000006
# Standard Deviation:  0.47134210010093014
# 25th Percentile (Perdicted):  -0.37116312500000004
# 50th Percentile (Predicted, also the median):  -0.13518616
# 75th Percentile (perdicted):  0.19339579750000002
# Interquartile Width (perdicted):  0.5645589225000001
#  Minimum:  -1.0843247
#  Maximum:  2.4027967
# Variance:  0.22216337532755526
# Skewness:  1.2216778787197176
# Kurtosis:  3.7357822182236893

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[4]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*265)
ax.fill_between(x,y*265,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Na23",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# 0.18114558
# Mean:  0.01877276341999995
# Standard Deviation:  0.9663505626387451
# 25th Percentile (Perdicted):  -0.556302485
# 50th Percentile (Predicted, also the median):  -0.247134235
# 75th Percentile (perdicted):  0.195176855
# Interquartile Width (perdicted):  0.75147934
#  Minimum:  -0.95171654
#  Maximum:  4.8356004
# Variance:  0.9338334099122192
# Skewness:  2.541809684660512
# Kurtosis:  7.729521775613132

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[5]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*175)
ax.fill_between(x,y*175,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mg26",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -1.0646765716146933e-09
# Standard Deviation:  1.0000000046545385
# 25th Percentile (Perdicted):  -0.7382046
# 50th Percentile (Predicted, also the median):  -0.1673477
# 75th Percentile (perdicted):  0.6453574
# Interquartile Width (perdicted):  1.383562
#  Minimum:  -2.5287051
#  Maximum:  3.0097773
# Variance:  1.000000009309077
# Skewness:  0.5764907502356791
# Kurtosis:  0.2521024750593517

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[6]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Al27",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.07411907771105532
# Standard Deviation:  0.04320674425185352
# 25th Percentile (Perdicted):  -0.087132793
# 50th Percentile (Predicted, also the median):  -0.08264972
# 75th Percentile (perdicted):  -0.073749082
# Interquartile Width (perdicted):  0.013383711000000006
#  Minimum:  -0.09697904
#  Maximum:  0.41646186
# Variance:  0.0018668227488450775
# Skewness:  8.603181169747357
# Kurtosis:  88.9975836802544

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[7]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("P31",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.028262149088000177
# Standard Deviation:  0.9185149764158135
# 25th Percentile (Perdicted):  -0.672461785
# 50th Percentile (Predicted, also the median):  -0.098517312
# 75th Percentile (perdicted):  0.62405488
# Interquartile Width (perdicted):  1.296516665
#  Minimum:  -1.656385
#  Maximum:  3.2694557
# Variance:  0.8436697619001423
# Skewness:  0.7411519966751422
# Kurtosis:  0.4323847264833973

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[8]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("S34",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.07052592530500007
# Standard Deviation:  0.015687494191457763
# 25th Percentile (Perdicted):  0.059652860999999995
# 50th Percentile (Predicted, also the median):  0.06806118
# 75th Percentile (perdicted):  0.07779707725
# Interquartile Width (perdicted):  0.018144216250000005
#  Minimum:  0.03912589
#  Maximum:  0.12992255
# Variance:  0.000246097474007021
# Skewness:  0.8280224648216049
# Kurtosis:  0.7479712459905947

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[9]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*290)
ax.fill_between(x,y*290,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("K39",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  3.334825942754433e-09
# Standard Deviation:  0.9999999953499994
# 25th Percentile (Perdicted):  -0.65758353
# 50th Percentile (Predicted, also the median):  -0.072091386
# 75th Percentile (perdicted):  0.52058715
# Interquartile Width (perdicted):  1.17817068
#  Minimum:  -3.6493363
#  Maximum:  3.8573403
# Variance:  0.9999999906999988
# Skewness:  0.5524295805563835
# Kurtosis:  1.8140938798438766

# %% [markdown]
# This dataset exhibts slight skewness as well as kurtosis, in the same direction. In this case a transformation may be the most appropriate if any action is needed.

# %%
ion = data[10]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*210)
ax.fill_between(x,y*210,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ca44",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -3.8009950123803e-09
# Standard Deviation:  1.0000000034979855
# 25th Percentile (Perdicted):  -0.6255581
# 50th Percentile (Predicted, also the median):  -0.18815446
# 75th Percentile (perdicted):  0.612863
# Interquartile Width (perdicted):  1.2384211
#  Minimum:  -2.2541094
#  Maximum:  4.0510287
# Variance:  1.0000000069959711
# Skewness:  0.8592572310211924
# Kurtosis:  1.659571099606664

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[11]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*300)
ax.fill_between(x,y*300,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Fe54",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.062165966306000006
# Standard Deviation:  0.4736407307487348
# 25th Percentile (Perdicted):  -0.36472198999999994
# 50th Percentile (Predicted, also the median):  -0.15342061499999998
# 75th Percentile (perdicted):  0.1398370325
# Interquartile Width (perdicted):  0.5045590225
#  Minimum:  -0.8851606
#  Maximum:  2.5909102
# Variance:  0.22433554182419552
# Skewness:  1.6237017317780167
# Kurtosis:  5.3455022464993105

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[12]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*320)
ax.fill_between(x,y*320,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mn55",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  1.0970149714002254e-09
# Standard Deviation:  0.9999999889327513
# 25th Percentile (Perdicted):  -0.6747931
# 50th Percentile (Predicted, also the median):  -0.19652131
# 75th Percentile (perdicted):  0.5474226
# Interquartile Width (perdicted):  1.2222157
#  Minimum:  -2.5533838
#  Maximum:  5.2247415
# Variance:  0.9999999778655028
# Skewness:  1.7619645090300955
# Kurtosis:  6.1827366648827

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[13]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*380)
ax.fill_between(x,y*380,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Co59",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -5.905970167866244e-09
# Standard Deviation:  0.9999999863115614
# 25th Percentile (Perdicted):  -0.7086921
# 50th Percentile (Predicted, also the median):  -0.22589222
# 75th Percentile (perdicted):  0.417081
# Interquartile Width (perdicted):  1.1257731
#  Minimum:  -1.3191382
#  Maximum:  5.812743
# Variance:  0.999999972623123
# Skewness:  2.34079413849053
# Kurtosis:  9.142923367271653

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[14]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*350)
ax.fill_between(x,y*350,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ni60",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.05544206940100001
# Standard Deviation:  0.6197434533220116
# 25th Percentile (Perdicted):  -0.25123271999999996
# 50th Percentile (Predicted, also the median):  -0.166872935
# 75th Percentile (perdicted):  0.018100516
# Interquartile Width (perdicted):  0.269333236
#  Minimum:  -0.350569
#  Maximum:  3.9596767
# Variance:  0.3840819479354924
# Skewness:  3.4400162945598387
# Kurtosis:  14.173333880313205

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[15]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*360)
ax.fill_between(x,y*360,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cu63",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.01224812529499997
# Standard Deviation:  0.9872792287014259
# 25th Percentile (Perdicted):  -0.7154431000000001
# 50th Percentile (Predicted, also the median):  -0.2356274
# 75th Percentile (perdicted):  0.425344525
# Interquartile Width (perdicted):  1.1407876250000002
#  Minimum:  -1.1604137
#  Maximum:  5.673328
# Variance:  0.9747202754252824
# Skewness:  1.8352713418673348
# Kurtosis:  5.6148780305362935

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[16]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Zn66",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.024513213404000034
# Standard Deviation:  0.9400200844508074
# 25th Percentile (Perdicted):  -0.58818527
# 50th Percentile (Predicted, also the median):  -0.23977136
# 75th Percentile (perdicted):  0.40427289999999994
# Interquartile Width (perdicted):  0.9924581699999999
#  Minimum:  -1.4047147
#  Maximum:  5.2591844
# Variance:  0.883637759170903
# Skewness:  2.0787777000152023
# Kurtosis:  6.944125760967007

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[17]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*490)
ax.fill_between(x,y*490,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("As75",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.07503540696666665
# Standard Deviation:  0.04996689173073897
# 25th Percentile (Perdicted):  -0.10131205875
# 50th Percentile (Predicted, also the median):  -0.089429395
# 75th Percentile (perdicted):  -0.05916727425
# Interquartile Width (perdicted):  0.042144784500000004
#  Minimum:  -0.14213334
#  Maximum:  0.29458138
# Variance:  0.0024966902692313904
# Skewness:  3.280174616232049
# Kurtosis:  17.617549899331124

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[18]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Se78",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -5.970149054504754e-10
# Standard Deviation:  1.0000000109592369
# 25th Percentile (Perdicted):  -0.5921643
# 50th Percentile (Predicted, also the median):  -0.23014803
# 75th Percentile (perdicted):  0.23471576
# Interquartile Width (perdicted):  0.8268800599999999
#  Minimum:  -1.0966915
#  Maximum:  6.739368
# Variance:  1.0000000219184737
# Skewness:  3.0127057852354926
# Kurtosis:  14.211063036646019

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[19]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Rb85",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -2.378109436294968e-09
# Standard Deviation:  0.9999999957401777
# 25th Percentile (Perdicted):  -0.70863974
# 50th Percentile (Predicted, also the median):  -0.22083536
# 75th Percentile (perdicted):  0.6516022
# Interquartile Width (perdicted):  1.3602419399999999
#  Minimum:  -1.8872966
#  Maximum:  3.0530498
# Variance:  0.9999999914803555
# Skewness:  0.6967539869537364
# Kurtosis:  0.30010173276771823

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[20]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*280)
ax.fill_between(x,y*280,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Sr88",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -7.139303288959019e-10
# Standard Deviation:  1.0000000025552684
# 25th Percentile (Perdicted):  -0.57519263
# 50th Percentile (Predicted, also the median):  -0.21187888
# 75th Percentile (perdicted):  0.18189053
# Interquartile Width (perdicted):  0.75708316
#  Minimum:  -0.97624254
#  Maximum:  5.801211
# Variance:  1.0000000051105369
# Skewness:  2.818161449400937
# Kurtosis:  11.034006277946562

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[21]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mo98",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.06732145908150006
# Standard Deviation:  0.2991312403922543
# 25th Percentile (Perdicted):  -0.15120201
# 50th Percentile (Predicted, also the median):  -0.0043061301
# 75th Percentile (perdicted):  0.1891678525
# Interquartile Width (perdicted):  0.3403698625
#  Minimum:  -0.3061154
#  Maximum:  1.635374
# Variance:  0.08947949897860863
# Skewness:  1.6461519731909264
# Kurtosis:  4.032245806740487

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.
