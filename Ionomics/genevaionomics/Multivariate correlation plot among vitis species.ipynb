# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = np.genfromtxt('Geneva Ionomics_Y.csv',delimiter = ',')
data = pd.DataFrame(data)
plt.rcParams['figure.figsize'] = (20,10)

# %%
plt.matshow(data.corr())
data.corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN  0.062561  0.074731  0.008581  0.035289  0.080364 -0.029623
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   0.062561 NaN  1.000000 -0.039607 -0.172870  0.885499 -0.343946 -0.881954
# 3   0.074731 NaN -0.039607  1.000000  0.166626 -0.250954  0.423801  0.269460
# 4   0.008581 NaN -0.172870  0.166626  1.000000 -0.171501  0.420046  0.183593
# 5   0.035289 NaN  0.885499 -0.250954 -0.171501  1.000000 -0.386848 -0.997432
# 6   0.080364 NaN -0.343946  0.423801  0.420046 -0.386848  1.000000  0.408145
# 7  -0.029623 NaN -0.881954  0.269460  0.183593 -0.997432  0.408145  1.000000
# 8   0.073757 NaN -0.146236  0.419185  0.269071 -0.246182  0.600626  0.262336
# 9   0.047899 NaN -0.158114 -0.078414  0.294632 -0.164026  0.078014  0.165311
# 10  0.064053 NaN  0.822432 -0.176941 -0.113014  0.881824 -0.239893 -0.877921
# ...

# %%
#acerfolia
plt.matshow(data[0:18].corr())
data[0:18].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN -0.181865  0.378340 -0.430904 -0.220903 -0.191956 -0.414451
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -0.181865 NaN  1.000000  0.274495  0.124790 -0.206847 -0.469777 -0.021318
# 3   0.378340 NaN  0.274495  1.000000 -0.086849  0.219146 -0.046305  0.126345
# 4  -0.430904 NaN  0.124790 -0.086849  1.000000  0.189528  0.600009  0.787454
# 5  -0.220903 NaN -0.206847  0.219146  0.189528  1.000000  0.506305  0.423873
# 6  -0.191956 NaN -0.469777 -0.046305  0.600009  0.506305  1.000000  0.643871
# 7  -0.414451 NaN -0.021318  0.126345  0.787454  0.423873  0.643871  1.000000
# 8   0.105596 NaN -0.370639  0.415296  0.120252  0.580931  0.548392  0.396052
# 9  -0.200760 NaN  0.205398 -0.020673  0.699899  0.093848  0.513654  0.626527
# 10 -0.205850 NaN  0.506361  0.153496  0.380333 -0.207412 -0.076911  0.375043
# ...

# %%
#cinera
plt.matshow(data[19:47].corr())
data[19:47].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN  0.127913  0.174910  0.292728  0.102609  0.242680 -0.068708
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   0.127913 NaN  1.000000  0.655930 -0.030525  0.264448  0.294882  0.078573
# 3   0.174910 NaN  0.655930  1.000000 -0.113298  0.430213  0.372007  0.136283
# 4   0.292728 NaN -0.030525 -0.113298  1.000000  0.003466  0.359210  0.253604
# 5   0.102609 NaN  0.264448  0.430213  0.003466  1.000000  0.098870  0.105726
# 6   0.242680 NaN  0.294882  0.372007  0.359210  0.098870  1.000000  0.320472
# 7  -0.068708 NaN  0.078573  0.136283  0.253604  0.105726  0.320472  1.000000
# 8   0.286537 NaN  0.327873  0.544766  0.060936  0.034076  0.656548  0.036401
# 9  -0.039185 NaN -0.298551 -0.332662  0.392736 -0.003022  0.064837  0.528411
# 10 -0.162536 NaN  0.120264  0.104835  0.485446 -0.029598  0.512080  0.256866
# ...

# %%
#labrusca
plt.matshow(data[48:87].corr())
data[48:87].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN  0.146269  0.078943  0.176414  0.053631  0.175186  0.181166
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   0.146269 NaN  1.000000  0.434878 -0.190859  0.427359  0.208198  0.260263
# 3   0.078943 NaN  0.434878  1.000000 -0.285120  0.122507  0.541731  0.177870
# 4   0.176414 NaN -0.190859 -0.285120  1.000000  0.034626 -0.273158  0.139308
# 5   0.053631 NaN  0.427359  0.122507  0.034626  1.000000  0.033935  0.132423
# 6   0.175186 NaN  0.208198  0.541731 -0.273158  0.033935  1.000000  0.366640
# 7   0.181166 NaN  0.260263  0.177870  0.139308  0.132423  0.366640  1.000000
# 8   0.179213 NaN  0.465125  0.404537 -0.404779  0.117374  0.595456  0.129099
# 9   0.068453 NaN -0.191703 -0.418365  0.646409 -0.025315 -0.592431  0.065576
# 10  0.072119 NaN  0.305658  0.073020  0.440196  0.070152 -0.220641  0.519756
# ...

# %%
#palmata, poorly represented
plt.matshow(data[88:92].corr())
data[88:92].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN -0.187301 -0.026599  0.700959 -0.649915 -0.218026  0.520131
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -0.187301 NaN  1.000000 -0.024456 -0.436251 -0.280018 -0.835059 -0.902267
# 3  -0.026599 NaN -0.024456  1.000000  0.632230 -0.610519  0.428913  0.251640
# 4   0.700959 NaN -0.436251  0.632230  1.000000 -0.739898  0.378720  0.773776
# 5  -0.649915 NaN -0.280018 -0.610519 -0.739898  1.000000  0.252258 -0.157392
# 6  -0.218026 NaN -0.835059  0.428913  0.378720  0.252258  1.000000  0.712841
# 7   0.520131 NaN -0.902267  0.251640  0.773776 -0.157392  0.712841  1.000000
# 8  -0.828929 NaN  0.567593 -0.359931 -0.948740  0.603877 -0.340226 -0.864222
# 9   0.836889 NaN -0.686187  0.089328  0.815280 -0.384657  0.336018  0.899928
# 10  0.819755 NaN -0.041636 -0.586038  0.178863 -0.219826 -0.502970  0.197709
# ...

# %%
#riparia
plt.matshow(data[93:163].corr())
data[93:163].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN -0.059387 -0.010084 -0.174645  0.014348 -0.119969  0.134548
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -0.059387 NaN  1.000000  0.373241 -0.162865  0.088806 -0.226750 -0.116500
# 3  -0.010084 NaN  0.373241  1.000000 -0.114096  0.302965 -0.197978 -0.169280
# 4  -0.174645 NaN -0.162865 -0.114096  1.000000  0.065460  0.359183  0.236837
# 5   0.014348 NaN  0.088806  0.302965  0.065460  1.000000 -0.173898  0.013375
# 6  -0.119969 NaN -0.226750 -0.197978  0.359183 -0.173898  1.000000  0.523468
# 7   0.134548 NaN -0.116500 -0.169280  0.236837  0.013375  0.523468  1.000000
# 8  -0.149936 NaN -0.045759 -0.110324  0.381556  0.287959  0.216342  0.046185
# 9   0.024768 NaN  0.033042 -0.188221  0.285792 -0.285379  0.058513  0.085811
# 10  0.147195 NaN  0.031966  0.033810  0.045028  0.016636  0.100393  0.343255
# ...

# %%
#rupestris
plt.matshow(data[164:190].corr())
data[164:190].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN  0.202196  0.014564  0.290919  0.040267  0.065444  0.194084
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2   0.202196 NaN  1.000000  0.537344  0.180240  0.129960 -0.402179 -0.278216
# 3   0.014564 NaN  0.537344  1.000000  0.213399  0.020403 -0.086712  0.054650
# 4   0.290919 NaN  0.180240  0.213399  1.000000  0.060993  0.399381  0.137507
# 5   0.040267 NaN  0.129960  0.020403  0.060993  1.000000  0.153461 -0.015497
# 6   0.065444 NaN -0.402179 -0.086712  0.399381  0.153461  1.000000  0.184694
# 7   0.194084 NaN -0.278216  0.054650  0.137507 -0.015497  0.184694  1.000000
# 8  -0.280440 NaN -0.127246  0.131469  0.109143  0.257008  0.675839  0.151961
# 9   0.435600 NaN  0.008367  0.035166  0.387867 -0.271861 -0.186940  0.210646
# 10  0.024333 NaN -0.157004 -0.038669  0.290365  0.174220  0.575972  0.186350
# ...

# %%
#vulpina
plt.matshow(data[191:201].corr())
data[191:201].corr()
# Out:
#           0   1         2         3         4         5         6         7   \
# 0   1.000000 NaN -0.116454 -0.147233  0.333523 -0.234741  0.740026  0.350487
# 1        NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  -0.116454 NaN  1.000000  0.684117  0.440192  0.499346 -0.145074 -0.053687
# 3  -0.147233 NaN  0.684117  1.000000  0.626386  0.575135 -0.253554  0.482097
# 4   0.333523 NaN  0.440192  0.626386  1.000000  0.511761  0.122022  0.596680
# 5  -0.234741 NaN  0.499346  0.575135  0.511761  1.000000 -0.271047  0.257028
# 6   0.740026 NaN -0.145074 -0.253554  0.122022 -0.271047  1.000000  0.394015
# 7   0.350487 NaN -0.053687  0.482097  0.596680  0.257028  0.394015  1.000000
# 8   0.138509 NaN  0.295990  0.211465  0.162300  0.497785  0.349525  0.361661
# 9   0.304555 NaN -0.115509  0.258162  0.588009  0.038720  0.234843  0.567890
# 10  0.187428 NaN  0.718899  0.786329  0.781594  0.479590  0.111916  0.574402
# ...

# %%
ion = data[2]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("B11",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# 91.82872738
# Mean:  79.43053095014926
# Standard Deviation:  46.91880836225791
# 25th Percentile (Perdicted):  62.06690195
# 50th Percentile (Predicted, also the median):  73.1546933
# 75th Percentile (perdicted):  88.82988063
# Interquartile Width (perdicted):  26.762978680000003
#  Minimum:  28.55530997
#  Maximum:  663.5921494
# Variance:  2201.374578134283
# Skewness:  9.832343660101298
# Kurtosis:  121.06690799478801
