# %%
install.packages("viridis", lib = "C:/Users/Public/Documents/R Packages")
library("viridis")
install.packages("missMDA", lib = "C:/Users/Public/Documents/R Packages")
library("missMDA")
install.packages("factoextra", lib = "C:/Users/Public/Documents/R Packages")
library("factoextra")
install.packages("MASS", lib = "C:/Users/Public/Documents/R Packages")
library("MASS")
install.packages("ggplot2", lib = "C:/Users/Public/Documents/R Packages")
library("ggplot2")
install.packages("ggfortify", lib = "C:/Users/Public/Documents/R Packages")
library("ggfortify")
# Out:
# package 'viridis' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Labcomp1\AppData\Local\Temp\Rtmpcp9O56\downloaded_packages
# Warning message:
# "package 'viridis' was built under R version 3.6.2"
# Loading required package: viridisLite
#
# Warning message:
# "package 'viridisLite' was built under R version 3.6.2"
# package 'missMDA' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Labcomp1\AppData\Local\Temp\Rtmpcp9O56\downloaded_packages
# Warning message:
# "package 'missMDA' was built under R version 3.6.2"
# package 'factoextra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Labcomp1\AppData\Local\Temp\Rtmpcp9O56\downloaded_packages
# Warning message:
# "package 'factoextra' was built under R version 3.6.2"
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 3.6.2"
# ...

# %%
Elements <- read.csv("Transformed_Boxplots_Z.csv")
Elements$Spec_int <- as.factor(Elements$Spec_int)

# %%
boxplot(Elements$B11~Elements$Spec_int) #Boron
Boron <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$B11)) + 
  geom_violin() 
Boron
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Na23~Elements$Spec_int) #sodium
sodium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Na23)) + 
  geom_violin()
sodium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Mg26~Elements$Spec_int) #magnesium
magnesium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Mg26)) + 
  geom_violin()
magnesium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Al27~Elements$Spec_int) #aluminium
aluminum <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Al27)) + 
  geom_violin()
aluminum
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$P31~Elements$Spec_int) #phosphorus
Phosphorus <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$P31)) + 
  geom_violin()
Phosphorus
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$S34~Elements$Spec_int) #sulfur
sulfur <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$S34)) + 
  geom_violin()
sulfur
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$K39~Elements$Spec_int) #potassium
potassium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$K39)) + 
  geom_violin()
potassium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Ca44~Elements$Spec_int) #calcium
calcium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Ca44)) + 
  geom_violin()
calcium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Fe54~Elements$Spec_int) #iron
iron <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Fe54)) + 
  geom_violin()
iron
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Mn55~Elements$Spec_int) #Manganese
manganese <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Mn55)) + 
  geom_violin()
manganese
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Co59~Elements$Spec_int) #cobalt
cobalt <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Co59)) + 
  geom_violin()
cobalt
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Ni60~Elements$Spec_int) #nickel
Nickel <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Ni60)) + 
  geom_violin()
Nickel
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Cu63~Elements$Spec_int) #copper
copper <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Cu63)) + 
  geom_violin()
copper
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Zn66~Elements$Spec_int) #zinc
Zinc <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Zn66)) + 
  geom_violin()
Zinc
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$As75~Elements$Spec_int) #arsenic
arsenic <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$As75)) + 
  geom_violin()
arsenic
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_ydensity)."
# plot without title
# plot without title

# %%
boxplot(Elements$Rb85~Elements$Spec_int) #rubiudium
rubidium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Rb85)) + 
  geom_violin()
rubidium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Sr88~Elements$Spec_int) #strontium
strontium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Sr88)) + 
  geom_violin()
strontium
# Out:
# plot without title
# plot without title

# %%
boxplot(Elements$Mo98~Elements$Spec_int) #molybdenum
# Out:
# plot without title

# %%
boxplot(Elements$Cd111~Elements$Spec_int) #cadmium
# Out:
# plot without title
