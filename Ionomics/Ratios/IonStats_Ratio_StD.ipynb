# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data0 = np.genfromtxt('New_ionStats_Ratio.csv',delimiter = ',', skip_header = 1)
data0 = pd.DataFrame(data0)
data = data0.drop(data0.columns[0:2],axis=1)
plt.rcParams['figure.figsize'] = (20,10)

# %%
data
# Out:
#       2         3         4         5         6    7         8         9   \
# 0    1.0  2.130652  1.397983 -0.437866 -0.269650  1.0  1.446109 -0.385877
# 1    1.0  0.544881  0.142998 -0.758713 -0.295083  1.0  0.345382 -0.703764
# 2    1.0 -0.158108  0.041047 -0.830973 -0.408410  1.0 -0.725725 -0.961033
# 3    1.0  1.606367  1.399045 -0.900557 -0.294662  1.0  0.012803 -0.890000
# 4    1.0  0.079618 -0.337583 -0.838549 -0.312775  1.0 -0.068778 -1.604688
# ..   ...       ...       ...       ...       ...  ...       ...       ...
# 413  9.0 -0.767316 -0.747814  1.525393 -0.094604  1.0 -1.692412 -1.412350
# 414  9.0 -0.004446 -0.777792  1.800752 -0.224705  1.0 -0.583268 -0.051852
# 415  9.0 -0.790960 -0.770752  0.218160 -0.536862  1.0 -0.045679  0.552529
# 416  9.0 -0.694744 -0.257418  2.602773  1.479790  1.0 -0.029635 -0.461812
# 417  9.0 -0.851412 -0.541133  0.654810  0.037032  1.0 -0.657494 -1.141738
#
#            10        11        12        13        14        15        16  \
# 0   -0.238538  1.279319  2.344757  0.352187 -0.227035  0.182361  1.337192
# 1   -0.818890  0.173024  0.572087 -0.698416 -0.890274 -0.128693  0.350537
# 2   -0.838600 -0.542836  0.029955 -1.068659 -0.726425  0.017634 -0.264329
# 3   -0.909623 -0.052120  1.607576 -0.309496 -0.841294 -0.516176  1.302068
# 4   -0.994551 -0.555596  0.535357 -0.682972 -0.709360  1.273621  0.259169
# ..        ...       ...       ...       ...       ...       ...       ...
# 413  1.515734 -0.175919 -0.144312  0.172521  0.331933 -0.798238 -0.725962
# 414  1.700623  0.219977 -0.519884  0.401646  0.092371 -0.797166 -0.385492
# 415  0.482663 -0.552758 -0.940312 -0.441181 -0.210386 -0.677991 -0.533321
# 416  1.782921  1.611353 -0.601275  1.507083  1.011041 -0.628490 -0.641637
# 417  0.751814 -0.116761 -0.649637 -0.172978  0.002470 -0.775261 -0.921012
#
#            17        18        19        20        21
# 0   -0.314329 -0.155743  1.361618  0.918846  0.131134
# 1   -0.073033 -0.667534 -0.002964  0.185744  0.039556
# 2   -0.750400 -0.908267 -0.632126 -0.068294  0.638231
# 3    0.087579 -0.615488 -0.919824 -0.365607 -0.028250
# 4    0.263260 -0.921863 -1.046847 -1.120371 -0.050230
# ..        ...       ...       ...       ...       ...
# 413 -0.236221 -0.135694  1.323654 -0.321954 -0.318299
# 414  0.294105  1.276852  1.937376 -0.561996 -0.054000
# 415 -0.775327  0.374227 -0.181137 -0.128999 -0.311663
# 416  0.962010 -0.050210  1.673722  0.161137 -0.243813
# 417  0.498845  0.543941  0.783584 -0.547047 -0.180913
#
# [418 rows x 20 columns]

# %%
g1count=0 #gx count means group x count
g2count=0
g3count=0
g4count=0
g5count=0
g6count=0
g7count=0
g8count=0
g9count=0
for x in range(len(data[2])):
    if (data[2][x]==1):
        g1count+=1
    elif (data[2][x]==2):
        g2count+=1
    elif (data[2][x]==3):
        g3count+=1
    elif (data[2][x]==4):
        g4count+=1
    elif (data[2][x]==5):
        g5count+=1
    elif (data[2][x]==6):
        g6count+=1
    elif (data[2][x]==7):
        g7count+=1
    elif (data[2][x]==8):
        g8count+=1
    elif (data[2][x]==9):
        g9count+=1

# %%
print(g1count,g2count,g3count,g4count,g5count,g6count,g7count,g8count,g9count)
# Out:
# 12 6 29 40 5 71 26 11 218

# %%
g1 = data[0:g1count]
g2 = data[g1count:g1count+g2count]
g3 = data[g1count+g2count:g1count+g2count+g3count]
g4 = data[g1count+g2count+g3count:g1count+g2count+g3count+g4count]
g5 = data[g1count+g2count+g3count+g4count:g1count+g2count+g3count+g4count+g5count]
g6 = data[g1count+g2count+g3count+g4count+g5count:g1count+g2count+g3count+g4count+g5count+g6count]
g7 = data[g1count+g2count+g3count+g4count+g5count+g6count:g1count+g2count+g3count+g4count+g5count+g6count+g7count]
g8 = data[g1count+g2count+g3count+g4count+g5count+g6count+g7count:g1count+g2count+g3count+g4count+g5count+g6count+g7count+g8count]
g9 = data[g1count+g2count+g3count+g4count+g5count+g6count+g7count+g8count:g1count+g2count+g3count+g4count+g5count+g6count+g7count+g8count+g9count]

# %%
 #mgx is the mean of group x #stdx is the standard deviation of group x
std1 = g1.std()
std2 = g2.std()
std3 = g3.std()
std4 = g4.std()
std5 = g5.std()
std6 = g6.std()
std7 = g7.std()
std8 = g8.std()
std9 = g9.std()

# %%
stddf=pd.DataFrame()
stddf[0] = std1
stddf[1] = std2
stddf[2] = std3
stddf[3] = std4
stddf[4] = std5
stddf[5] = std6
stddf[6] = std7
stddf[7] = std8
stddf[8] = std9
stddf = stddf.transpose()
spec = pd.DataFrame(data = ["acerifolia","aestivalis", "cinerea", "labrusca", "palmata", "riparia", "rupestris", "vulpina", "rup_rip"])
stddf = pd.concat(objs = [spec,stddf], axis = 1)
stddf.drop(stddf.columns[1:2], axis = 1, inplace = True)
stddf
# Out:
#            0         3         4         5         6    7         8   \
# 0  acerifolia  1.337817  0.912411  0.235270  0.098448  0.0  1.005400
# 1  aestivalis  0.345472  0.594873  0.201524  0.083976  0.0  0.487680
# 2     cinerea  0.732140  1.165828  0.266224  0.467089  0.0  0.993957
# 3    labrusca  0.742647  0.939085  0.431470  0.314202  0.0  0.922083
# 4     palmata  0.503599  0.344974  0.102407  0.750493  0.0  0.331973
# 5     riparia  0.985852  1.300649  0.261197  0.185012  0.0  0.967288
# 6   rupestris  1.243434  0.658150  0.279647  0.125508  0.0  1.032022
# 7     vulpina  0.997988  0.898765  0.347485  0.208110  0.0  1.078998
# 8     rup_rip  0.334269  0.547860  0.739970  0.683181  0.0  0.979454
#
#          9         10        11        12        13        14        15  \
# 0  0.839900  0.221927  0.825699  0.798373  0.513328  0.249927  0.535707
# 1  0.748530  0.069912  0.472388  0.685453  0.322942  0.352069  0.685012
# 2  0.858621  0.264218  0.443934  0.868696  0.420249  1.223376  0.938115
# 3  0.930869  0.335516  0.493698  0.879499  0.435864  0.584695  0.716375
# 4  1.033435  0.234821  0.312610  0.493267  1.172066  3.431840  0.309358
# 5  1.346221  0.360026  0.869824  0.747454  0.423680  0.341891  0.503230
