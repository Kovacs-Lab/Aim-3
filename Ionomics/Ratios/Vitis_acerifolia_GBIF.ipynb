# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/Aim-3/Ionomics/Ratios'

# %%
data = pd.read_csv (r'/home/jovyan/Aim-3/Ionomics/Ratios/Vitis acerifolia.csv', sep='\t')
df = pd.DataFrame(data)
pd.set_option('max_columns', None)
print("Default max_rows: {} and min_rows: {}".format(pd.get_option("max_rows"), pd.get_option("min_rows")))
df
# Out:
# Default max_rows: None and min_rows: 10
#         gbifID                            datasetKey  \
# 0   2574971808  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 1   2574971704  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 2   2573369451  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 3   2573367751  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 4   2573338114  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 5   2573338043  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 6   2573335752  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 7   2573334832  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 8   2573334587  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 9   2573333466  7c5e863f-3f70-4933-b05d-fc57c66dd3f3
# 10  2422870889  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 11  2242390397  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 12  2242382263  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 13  2242381756  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 14  1949866863  d415c253-4d61-4459-9d25-4015b9084fb0
# 15  1949866032  d415c253-4d61-4459-9d25-4015b9084fb0
# ...
