# %%
install.packages("viridis")
library("viridis")
install.packages("missMDA")
library("missMDA")
install.packages("factoextra")
library("factoextra")
install.packages("MASS")
library("MASS")
install.packages("ggplot2")
library("ggplot2")
install.packages("ggfortify")
library("ggfortify")
# Out:
# also installing the dependency ‘gridExtra’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Loading required package: viridisLite
#
# also installing the dependencies ‘zip’, ‘SparseM’, ‘MatrixModels’, ‘sp’, ‘foreign’, ‘openxlsx’, ‘boot’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘maptools’, ‘rio’, ‘lme4’, ‘car’, ‘cluster’, ‘ellipse’, ‘flashClust’, ‘leaps’, ‘scatterplot3d’, ‘ggrepel’, ‘FactoMineR’, ‘mice’, ‘mvtnorm’, ‘doParallel’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# also installing the dependencies ‘ggsci’, ‘cowplot’, ‘ggsignif’, ‘polynom’, ‘dendextend’, ‘ggpubr’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
Elements <- read.csv("New_ionStats_Ratio.csv")

# %%
boxplot(Elements$B11~Elements$Spec_int) #Boron
Elements$Spec_int <- as.factor(Elements$Spec_int)
boron <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$B11)) + 
  geom_violin()
boron
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$B11` is discouraged. Use `B11` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Na23~Elements$Spec_int) #sodium
sodium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Na23)) + 
  geom_violin()
sodium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Na23` is discouraged. Use `Na23` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Mg26~Elements$Spec_int) #magnesium
magnesium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Mg26)) + 
  geom_violin()
magnesium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Mg26` is discouraged. Use `Mg26` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Al27~Elements$Spec_int) #aluminium
aluminium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Al27)) + 
  geom_violin()
aluminium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Al27` is discouraged. Use `Al27` instead.”
# Warning message:
# “Removed 5 rows containing non-finite values (stat_ydensity).”
# plot without title
# plot without title

# %%
boxplot(Elements$P31~Elements$Spec_int) #phosphorus #phosphorus is 0, as all elements are compared to it
phosphorus <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$P31)) + 
  geom_violin()
phosphorus
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$P31` is discouraged. Use `P31` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$S34~Elements$Spec_int) #sulfur
sulfur <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$S34)) + 
  geom_violin()
sulfur
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$S34` is discouraged. Use `S34` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$K39~Elements$Spec_int) #potassium
potassium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$K39)) + 
  geom_violin()
potassium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$K39` is discouraged. Use `K39` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Ca44~Elements$Spec_int) #calcium
calcium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Ca44)) + 
  geom_violin()
calcium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Ca44` is discouraged. Use `Ca44` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Fe54~Elements$Spec_int) #iron
iron <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Fe54)) + 
  geom_violin()
iron
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Fe54` is discouraged. Use `Fe54` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Mn55~Elements$Spec_int) #manganese
manganese <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Mn55)) + 
  geom_violin()
manganese
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Mn55` is discouraged. Use `Mn55` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Co59~Elements$Spec_int) #cobalt
cobalt <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Co59)) + 
  geom_violin()
cobalt
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Co59` is discouraged. Use `Co59` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Ni60~Elements$Spec_int) #nickel
nickel <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Ni60)) + 
  geom_violin()
nickel
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Ni60` is discouraged. Use `Ni60` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Cu63~Elements$Spec_int) #copper
copper <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Cu63)) + 
  geom_violin()
copper
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Cu63` is discouraged. Use `Cu63` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Zn66~Elements$Spec_int) #zinc
zinc <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Zn66)) + 
  geom_violin()
zinc
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Zn66` is discouraged. Use `Zn66` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$As75~Elements$Spec_int) #arsenic
arsenic <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$As75)) + 
  geom_violin()
arsenic
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$As75` is discouraged. Use `As75` instead.”
# Warning message:
# “Removed 6 rows containing non-finite values (stat_ydensity).”
# plot without title
# plot without title

# %%
boxplot(Elements$Rb85~Elements$Spec_int) #rubiudium
rubiudium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Rb85)) + 
  geom_violin()
rubiudium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Rb85` is discouraged. Use `Rb85` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Sr88~Elements$Spec_int) #strontium
strontium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Sr88)) + 
  geom_violin()
strontium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Sr88` is discouraged. Use `Sr88` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Mo98~Elements$Spec_int) #molybdenum
molybdenum <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Mo98)) + 
  geom_violin()
molybdenum
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Mo98` is discouraged. Use `Mo98` instead.”
# plot without title
# plot without title

# %%
boxplot(Elements$Cd111~Elements$Spec_int) #cadmium
cadmium <- ggplot(Elements, aes(x=Elements$Spec_int, y=Elements$Cd111)) + 
  geom_violin()
cadmium
# Out:
# Warning message:
# “Use of `Elements$Spec_int` is discouraged. Use `Spec_int` instead.”
# Warning message:
# “Use of `Elements$Cd111` is discouraged. Use `Cd111` instead.”
# Warning message:
# “Removed 5 rows containing non-finite values (stat_ydensity).”
# plot without title
# plot without title
