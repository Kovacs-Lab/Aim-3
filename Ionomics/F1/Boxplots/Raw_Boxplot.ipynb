# %%
install.packages("viridis")
library("viridis")
install.packages("missMDA")
library("missMDA")
install.packages("factoextra")
library("factoextra")
install.packages("MASS")
library("MASS")
install.packages("ggplot2")
library("ggplot2")
install.packages("ggfortify")
library("ggfortify")
# Out:
# Installing package into 'C:/Users/2198K/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'viridis' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\2198K\AppData\Local\Temp\RtmpGYJfA0\downloaded_packages
# Warning message:
# "package 'viridis' was built under R version 3.6.2"
# Loading required package: viridisLite
#
# Installing package into 'C:/Users/2198K/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'missMDA' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\2198K\AppData\Local\Temp\RtmpGYJfA0\downloaded_packages
# Warning message:
# "package 'missMDA' was built under R version 3.6.2"
# Installing package into 'C:/Users/2198K/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'factoextra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# ...

# %%
Elements <- read.csv("New_ionStats_boxplot.csv")

# %%
boxplot(Elements$Li7~Elements$Spec_int) #Li7
# Out:
# plot without title

# %%
boxplot(Elements$B11~Elements$Spec_int) #Boron
# Out:
# plot without title

# %%
boxplot(Elements$Na23~Elements$Spec_int) #sodium
# Out:
# plot without title

# %%
boxplot(Elements$Mg26~Elements$Spec_int) #magnesium
# Out:
# plot without title

# %%
boxplot(Elements$Al27~Elements$Spec_int) #aluminum
# Out:
# plot without title

# %%
boxplot(Elements$P31~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$S34~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$K39~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Ca44~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Fe54~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Mn55~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Co59~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Ni60~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Cu63~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Zn66~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$As75~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Se78~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Rb85~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Sr88~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Mo98~Elements$Spec_int)
# Out:
# plot without title

# %%
boxplot(Elements$Cd111~Elements$Spec_int)
# Out:
# plot without title
