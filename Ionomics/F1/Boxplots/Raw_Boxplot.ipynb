# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("New_ionstats_boxplot.csv", delimiter = ',')

data = pd.DataFrame(data)

# %%
np.random.seed(1234)
data = pd.DataFrame(np.random.randn(10, 21),
                  columns=["Li7", "B11","Na23", "Mg26", "Al27", "P31", "S34", "K39", "Ca44", "Fe54", "Mn55", "Co59", "Ni60", "Cu63", "Zn66", "As75", "Se78", "Rb85", "Sr88", "Mo98", "Cd111" ])
boxplot = data.boxplot(column=["Li7", "B11","Na23", "Mg26", "Al27", "P31", "S34", "K39", "Ca44", "Fe54", "Mn55", "Co59", "Ni60", "Cu63", "Zn66", "As75", "Se78", "Rb85", "Sr88", "Mo98", "Cd111" ],rot=45, fontsize=11)
