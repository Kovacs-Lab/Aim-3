# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = np.genfromtxt('IonStats.csv',delimiter = ',')
data = pd.DataFrame(data)
plt.rcParams['figure.figsize'] = (20,10)

# %%
plt.matshow(data.corr())

# %%
ion = data[1]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*300)
ax.fill_between(x,y*300,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Li7",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.038745850975961546
# Standard Deviation:  0.7528047566075851
# 25th Percentile (Perdicted):  -0.43986049875
# 50th Percentile (Predicted, also the median):  -0.2610577765
# 75th Percentile (perdicted):  0.0340703745
# Interquartile Width (perdicted):  0.47393087325
#  Minimum:  -0.810497354
#  Maximum:  4.63834224
# Variance:  0.5667150015710053
# Skewness:  3.530677802483103
# Kurtosis:  15.818653702136153

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[2]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("B11",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.0004411918990384366
# Standard Deviation:  1.0010922255062398
# 25th Percentile (Perdicted):  -0.7018743727500001
# 50th Percentile (Predicted, also the median):  -0.159757896
# 75th Percentile (perdicted):  0.6001553527500001
# Interquartile Width (perdicted):  1.3020297255000002
#  Minimum:  -2.081845645
#  Maximum:  3.407456208
# Variance:  1.0021856439690362
# Skewness:  0.8121984379181761
# Kurtosis:  0.43322860228249427

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[3]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5, bins = 50)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Na23",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.0046332965769230825
# Standard Deviation:  1.0223001335741806
# 25th Percentile (Perdicted):  -0.22934259299999998
# 50th Percentile (Predicted, also the median):  -0.06862889650000001
# 75th Percentile (perdicted):  0.08133292075
# Interquartile Width (perdicted):  0.31067551374999997
#  Minimum:  -0.508536377
#  Maximum:  14.23125096
# Variance:  1.0450975631057875
# Skewness:  13.146942621295455
# Kurtosis:  183.48458666558372

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[4]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mg26",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.006882920995192314
# Standard Deviation:  1.0087933501006126
# 25th Percentile (Perdicted):  -0.74635372
# 50th Percentile (Predicted, also the median):  -0.1454738235
# 75th Percentile (perdicted):  0.6284295710000001
# Interquartile Width (perdicted):  1.374783291
#  Minimum:  -2.613343074
#  Maximum:  3.408067077
# Variance:  1.017664023207217
# Skewness:  0.6683230844131024
# Kurtosis:  0.3504394449598327

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[5]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*410)
ax.fill_between(x,y*410,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Al27",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.041381506701923115
# Standard Deviation:  0.7575997937629494
# 25th Percentile (Perdicted):  -0.413528546
# 50th Percentile (Predicted, also the median):  -0.29590746
# 75th Percentile (perdicted):  -0.015716998000000003
# Interquartile Width (perdicted):  0.397811548
#  Minimum:  -0.599440462
#  Maximum:  4.889417852
# Variance:  0.5739574475096634
# Skewness:  3.8911755245840665
# Kurtosis:  18.714540386929624

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[6]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*200)
ax.fill_between(x,y*200,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("P31",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.006300620639423141
# Standard Deviation:  1.0111484237930617
# 25th Percentile (Perdicted):  -0.6465165745
# 50th Percentile (Predicted, also the median):  -0.11777552050000001
# 75th Percentile (perdicted):  0.591826789
# Interquartile Width (perdicted):  1.2383433634999998
#  Minimum:  -4.07045802
#  Maximum:  3.821616152
# Variance:  1.022421134939193
# Skewness:  0.2681677809658138
# Kurtosis:  1.4493058366903773

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[7]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*200)
ax.fill_between(x,y*200,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("S34",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.02554513883653848
# Standard Deviation:  1.0009943490775328
# 25th Percentile (Perdicted):  -0.5945041582499999
# 50th Percentile (Predicted, also the median):  -0.064701122
# 75th Percentile (perdicted):  0.4967341795
# Interquartile Width (perdicted):  1.09123833775
#  Minimum:  -3.263471761
#  Maximum:  4.179634768
# Variance:  1.0019896868851537
# Skewness:  0.6172515975862926
# Kurtosis:  1.6950638659845474

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[8]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("K39",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.006196544052884565
# Standard Deviation:  1.0100229952392548
# 25th Percentile (Perdicted):  -0.6863141205
# 50th Percentile (Predicted, also the median):  -0.186015169
# 75th Percentile (perdicted):  0.53625923475
# Interquartile Width (perdicted):  1.22257335525
#  Minimum:  -1.856457873
#  Maximum:  3.306604941
# Variance:  1.0201464509120757
# Skewness:  1.0388347797757176
# Kurtosis:  1.222540011676096

# %% [markdown]
# This dataset exhibts slight skewness as well as kurtosis, in the same direction. In this case a transformation may be the most appropriate if any action is needed.

# %%
ion = data[9]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ca44",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.021411040413461594
# Standard Deviation:  0.9989052179068486
# 25th Percentile (Perdicted):  -0.7217044099999999
# 50th Percentile (Predicted, also the median):  -0.0874549985
# 75th Percentile (perdicted):  0.6977573907500001
# Interquartile Width (perdicted):  1.41946180075
#  Minimum:  -2.4052177
#  Maximum:  2.938229026
# Variance:  0.9978116343615286
# Skewness:  0.18220133134642505
# Kurtosis:  -0.5258587969009372

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[10]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*300)
ax.fill_between(x,y*300,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Fe54",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.04393967102884611
# Standard Deviation:  0.7761340553987117
# 25th Percentile (Perdicted):  -0.47504644675
# 50th Percentile (Predicted, also the median):  -0.2448143895
# 75th Percentile (perdicted):  0.06415541975
# Interquartile Width (perdicted):  0.5392018665
#  Minimum:  -1.317069444
#  Maximum:  4.560449801
# Variance:  0.6023840719496505
# Skewness:  3.0846101994009176
# Kurtosis:  12.65403629764073

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[11]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*200)
ax.fill_between(x,y*200,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mn55",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.0010605058894230732
# Standard Deviation:  1.0163801716250749
# 25th Percentile (Perdicted):  -0.71789486225
# 50th Percentile (Predicted, also the median):  -0.31513049550000005
# 75th Percentile (perdicted):  0.49166436174999995
# Interquartile Width (perdicted):  1.209559224
#  Minimum:  -1.373779959
#  Maximum:  5.06423404
# Variance:  1.0330286532726167
# Skewness:  1.8834971704503556
# Kurtosis:  4.873152763310435

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[12]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*180)
ax.fill_between(x,y*180,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Co59",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.02753129158653843
# Standard Deviation:  0.8820098021892662
# 25th Percentile (Perdicted):  -0.6208903895
# 50th Percentile (Predicted, also the median):  -0.1931056975
# 75th Percentile (perdicted):  0.2344629285
# Interquartile Width (perdicted):  0.8553533179999999
#  Minimum:  -1.229277029
#  Maximum:  3.921126147
# Variance:  0.7779412911579484
# Skewness:  1.7206018975979263
# Kurtosis:  3.646611916909179

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[13]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*250)
ax.fill_between(x,y*250,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ni60",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.022817538894230778
# Standard Deviation:  0.9342209730756429
# 25th Percentile (Perdicted):  -0.6317937435000001
# 50th Percentile (Predicted, also the median):  -0.2147782175
# 75th Percentile (perdicted):  0.33404507625
# Interquartile Width (perdicted):  0.9658388197500001
#  Minimum:  -1.420403213
#  Maximum:  6.075937423
# Variance:  0.872768826534401
# Skewness:  2.4180591214466163
# Kurtosis:  10.920857082246897

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[14]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*180)
ax.fill_between(x,y*180,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cu63",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.00384973868269233
# Standard Deviation:  1.010602429884232
# 25th Percentile (Perdicted):  -0.74841040175
# 50th Percentile (Predicted, also the median):  -0.096364486
# 75th Percentile (perdicted):  0.66789418775
# Interquartile Width (perdicted):  1.4163045895
#  Minimum:  -4.387326665
#  Maximum:  3.64201578
# Variance:  1.021317271287914
# Skewness:  0.23815905513743735
# Kurtosis:  1.6078174769534046

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[15]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*200)
ax.fill_between(x,y*200,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Zn66",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.006707359062499944
# Standard Deviation:  1.011683557022495
# 25th Percentile (Perdicted):  -0.686533945
# 50th Percentile (Predicted, also the median):  -0.29837645749999997
# 75th Percentile (perdicted):  0.40224507800000003
# Interquartile Width (perdicted):  1.088779023
#  Minimum:  -1.2560576
#  Maximum:  5.17311005
# Variance:  1.0235036195496876
# Skewness:  2.2832711235387886
# Kurtosis:  7.645785899699162

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[16]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*230)
ax.fill_between(x,y*230,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("As75",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.01942423566346156
# Standard Deviation:  0.9206461587923845
# 25th Percentile (Perdicted):  -0.55208626875
# 50th Percentile (Predicted, also the median):  -0.2887536785
# 75th Percentile (perdicted):  0.09812149725
# Interquartile Width (perdicted):  0.650207766
#  Minimum:  -1.01936912
#  Maximum:  5.259666094
# Variance:  0.8475893496991725
# Skewness:  2.371789407170978
# Kurtosis:  7.0528599645423595

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[17]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*180)
ax.fill_between(x,y*180,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Rb85",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.014511135427884552
# Standard Deviation:  1.0142827092547797
# 25th Percentile (Perdicted):  -0.67520582975
# 50th Percentile (Predicted, also the median):  -0.218513349
# 75th Percentile (perdicted):  0.56036178725
# Interquartile Width (perdicted):  1.235567617
#  Minimum:  -1.454376794
#  Maximum:  4.856930753
# Variance:  1.028769414293216
# Skewness:  1.502976529731731
# Kurtosis:  3.617670109901633

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[18]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Sr88",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.018356696850961505
# Standard Deviation:  1.002504680843497
# 25th Percentile (Perdicted):  -0.68044080075
# 50th Percentile (Predicted, also the median):  -0.1281117195
# 75th Percentile (perdicted):  0.733121235
# Interquartile Width (perdicted):  1.41356203575
#  Minimum:  -2.155724895
#  Maximum:  2.84314611
# Variance:  1.0050156351131219
# Skewness:  0.19330901182026777
# Kurtosis:  -0.5406574976752943

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[19]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*180)
ax.fill_between(x,y*180,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mo98",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.03186703786057691
# Standard Deviation:  0.9551229254142614
# 25th Percentile (Perdicted):  -0.72837027125
# 50th Percentile (Predicted, also the median):  -0.2078874305
# 75th Percentile (perdicted):  0.43485434425
# Interquartile Width (perdicted):  1.1632246155
#  Minimum:  -2.946364171
#  Maximum:  3.442418852
# Variance:  0.9122598026518967
# Skewness:  0.7291780019369479
# Kurtosis:  0.9576189310265519

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[20]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*400)
ax.fill_between(x,y*400,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cd111",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.004932312091346138
# Standard Deviation:  1.0232085941714488
# 25th Percentile (Perdicted):  -0.20375897350000002
# 50th Percentile (Predicted, also the median):  -0.15212873249999997
# 75th Percentile (perdicted):  -0.0608646575
# Interquartile Width (perdicted):  0.14289431600000002
#  Minimum:  -0.314344587
#  Maximum:  12.41066952
# Variance:  1.0469558271863129
# Skewness:  10.177608763622482
# Kurtosis:  113.80017278914127

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.
