# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = np.genfromtxt('New_ionStats.csv',delimiter = ',')
data = pd.DataFrame(data)
plt.rcParams['figure.figsize'] = (20,10)

# %%
ion = data[2]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Li7",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.20334303
# Mean:  -0.04222134341342597
# Standard Deviation:  0.7387829120440857
# 25th Percentile (Perdicted):  -0.43293190000000004
# 50th Percentile (Predicted, also the median):  -0.26282689000000004
# 75th Percentile (perdicted):  0.02939176525
# Interquartile Width (perdicted):  0.46232366525
#  Minimum:  -0.7432487
#  Maximum:  4.6383424
# Variance:  0.5458001911283393
# Skewness:  3.613501735822687
# Kurtosis:  16.58016412724362
# C:\Users\daeda\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\daeda\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[3]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("B11",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.0528921
# Mean:  -5.077981652140939e-09
# Standard Deviation:  1.000000004691828
# 25th Percentile (Perdicted):  -0.7020273850000001
# 50th Percentile (Predicted, also the median):  -0.15208987000000002
# 75th Percentile (perdicted):  0.5932011225
# Interquartile Width (perdicted):  1.2952285075
#  Minimum:  -2.0818458
#  Maximum:  3.4074562
# Variance:  1.0000000093836563
# Skewness:  0.7735872047190174
# Kurtosis:  0.35793543021376895

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[4]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*265)
ax.fill_between(x,y*265,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Na23",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.32871976
# Mean:  -0.06558180138202764
# Standard Deviation:  0.25035331717049075
# 25th Percentile (Perdicted):  -0.23058769
# 50th Percentile (Predicted, also the median):  -0.06982637
# 75th Percentile (perdicted):  0.08021987
# Interquartile Width (perdicted):  0.31080756
#  Minimum:  -0.5085364
#  Maximum:  1.0571939
# Variance:  0.06267678341826834
# Skewness:  0.8707122437752765
# Kurtosis:  1.4915487234836915

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[5]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*175)
ax.fill_between(x,y*175,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mg26",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -8.486238546741184e-10
# Standard Deviation:  0.9999999977631838
# 25th Percentile (Perdicted):  -0.70584805
# 50th Percentile (Predicted, also the median):  -0.15839523
# 75th Percentile (perdicted):  0.6377523875000001
# Interquartile Width (perdicted):  1.3436004375000001
#  Minimum:  -2.613343
#  Maximum:  3.408067
# Variance:  0.9999999955263676
# Skewness:  0.6627608287246411
# Kurtosis:  0.34017334017607315

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[6]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Al27",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.04546192414377877
# Standard Deviation:  0.7429564175601261
# 25th Percentile (Perdicted):  -0.41342816
# 50th Percentile (Predicted, also the median):  -0.27890533
# 75th Percentile (perdicted):  -0.016156191
# Interquartile Width (perdicted):  0.397271969
#  Minimum:  -0.59944046
#  Maximum:  4.8894176
# Variance:  0.5519842383937764
# Skewness:  3.968323092288359
# Kurtosis:  19.56498076521818

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[7]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("P31",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  1.958715574036995e-09
# Standard Deviation:  0.9999999982780254
# 25th Percentile (Perdicted):  -0.653077325
# 50th Percentile (Predicted, also the median):  -0.11777552
# 75th Percentile (perdicted):  0.6112774125
# Interquartile Width (perdicted):  1.2643547375000002
#  Minimum:  -4.070458
#  Maximum:  3.8216162
# Variance:  0.9999999965560509
# Skewness:  0.2764259077769213
# Kurtosis:  1.4611660666457507

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[8]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("S34",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  3.518348960797577e-10
# Standard Deviation:  1.000000000879211
# 25th Percentile (Perdicted):  -0.6237484375000001
# 50th Percentile (Predicted, also the median):  -0.08738795499999999
# 75th Percentile (perdicted):  0.488941435
# Interquartile Width (perdicted):  1.1126898725
#  Minimum:  -3.2634718
#  Maximum:  4.1796346
# Variance:  1.0000000017584219
# Skewness:  0.6193376837630592
# Kurtosis:  1.6431795660079453

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[9]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*290)
ax.fill_between(x,y*290,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("K39",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  3.9357798096040125e-09
# Standard Deviation:  1.0000000117891958
# 25th Percentile (Perdicted):  -0.681108425
# 50th Percentile (Predicted, also the median):  -0.17288483
# 75th Percentile (perdicted):  0.509510735
# Interquartile Width (perdicted):  1.19061916
#  Minimum:  -1.8564578
#  Maximum:  3.3066049
# Variance:  1.0000000235783917
# Skewness:  1.0533482400261516
# Kurtosis:  1.2747269715783922

# %% [markdown]
# This dataset exhibts slight skewness as well as kurtosis, in the same direction. In this case a transformation may be the most appropriate if any action is needed.

# %%
ion = data[10]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*210)
ax.fill_between(x,y*210,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ca44",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -1.4587155489636613e-09
# Standard Deviation:  0.9999999973668073
# 25th Percentile (Perdicted):  -0.7197662599999999
# 50th Percentile (Predicted, also the median):  -0.06381223
# 75th Percentile (perdicted):  0.75002725
# Interquartile Width (perdicted):  1.46979351
#  Minimum:  -2.4052176
#  Maximum:  2.938229
# Variance:  0.9999999947336147
# Skewness:  0.1598496251590654
# Kurtosis:  -0.5589625050408369

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[11]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*300)
ax.fill_between(x,y*300,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Fe54",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.04381174020935492
# Standard Deviation:  0.7643613325078918
# 25th Percentile (Perdicted):  -0.4673023
# 50th Percentile (Predicted, also the median):  -0.24178775
# 75th Percentile (perdicted):  0.055837154
# Interquartile Width (perdicted):  0.5231394540000001
#  Minimum:  -1.3170694
#  Maximum:  4.5604496
# Variance:  0.5842482466332399
# Skewness:  3.0997736379419765
# Kurtosis:  12.939882442912538

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[12]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*320)
ax.fill_between(x,y*320,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mn55",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  1.9105504446597537e-09
# Standard Deviation:  1.0000000076845192
# 25th Percentile (Perdicted):  -0.7113525375
# 50th Percentile (Predicted, also the median):  -0.29147592499999997
# 75th Percentile (perdicted):  0.4673046599999999
# Interquartile Width (perdicted):  1.1786571975
#  Minimum:  -1.37378
#  Maximum:  5.0642343
# Variance:  1.0000000153690385
# Skewness:  1.8995548075753543
# Kurtosis:  5.03496687948905

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[13]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*380)
ax.fill_between(x,y*380,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Co59",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  7.201834656157138e-11
# Standard Deviation:  0.9999999968443286
# 25th Percentile (Perdicted):  -0.612794725
# 50th Percentile (Predicted, also the median):  -0.198274435
# 75th Percentile (perdicted):  0.257372225
# Interquartile Width (perdicted):  0.87016695
#  Minimum:  -1.229277
#  Maximum:  7.2076674
# Variance:  0.9999999936886572
# Skewness:  2.8081070447915866
# Kurtosis:  13.492861312738476

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[14]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*350)
ax.fill_between(x,y*350,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ni60",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -1.5463302752175486e-09
# Standard Deviation:  0.9999999940767788
# 25th Percentile (Perdicted):  -0.626027425
# 50th Percentile (Predicted, also the median):  -0.212385475
# 75th Percentile (perdicted):  0.341543825
# Interquartile Width (perdicted):  0.96757125
#  Minimum:  -1.4204032
#  Maximum:  6.0759373
# Variance:  0.9999999881535576
# Skewness:  2.767542628156025
# Kurtosis:  12.601844786559692

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[15]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*360)
ax.fill_between(x,y*360,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cu63",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -1.020642212947344e-09
# Standard Deviation:  0.9999999999016037
# 25th Percentile (Perdicted):  -0.738269345
# 50th Percentile (Predicted, also the median):  -0.107392975
# 75th Percentile (perdicted):  0.65825504
# Interquartile Width (perdicted):  1.396524385
#  Minimum:  -4.3873267
#  Maximum:  3.6420157
# Variance:  0.9999999998032075
# Skewness:  0.24873941495816138
# Kurtosis:  1.613937477658074

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[16]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Zn66",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -4.660550465811425e-09
# Standard Deviation:  0.9999999875399144
# 25th Percentile (Perdicted):  -0.66108556
# 50th Percentile (Predicted, also the median):  -0.28345521
# 75th Percentile (perdicted):  0.3957776975
# Interquartile Width (perdicted):  1.0568632574999999
#  Minimum:  -1.2560576
#  Maximum:  5.17311
# Variance:  0.999999975079829
# Skewness:  2.256420215353195
# Kurtosis:  7.6077215529422135

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[17]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*490)
ax.fill_between(x,y*490,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("As75",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -3.454128542823259e-10
# Standard Deviation:  1.0000000053213556
# 25th Percentile (Perdicted):  -0.5492673750000001
# 50th Percentile (Predicted, also the median):  -0.292024325
# 75th Percentile (perdicted):  0.11471955625
# Interquartile Width (perdicted):  0.6639869312500001
#  Minimum:  -1.0193691
#  Maximum:  6.2881413
# Variance:  1.0000000106427112
# Skewness:  2.87096892515162
# Kurtosis:  11.140340463887096

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[18]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Se78",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.05978299218011695
# Standard Deviation:  0.03830482606082917
# 25th Percentile (Perdicted):  -0.07236757499999999
# 50th Percentile (Predicted, also the median):  -0.06990365
# 75th Percentile (perdicted):  -0.065518212
# Interquartile Width (perdicted):  0.006849362999999983
#  Minimum:  -0.075217955
#  Maximum:  0.25231612
# Variance:  0.0014672596995503773
# Skewness:  5.82025064850342
# Kurtosis:  38.59956781100639

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[19]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Rb85",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -1.0201834298339078e-09
# Standard Deviation:  1.0000000023444966
# 25th Percentile (Perdicted):  -0.68014352
# 50th Percentile (Predicted, also the median):  -0.218513345
# 75th Percentile (perdicted):  0.5305216724999999
# Interquartile Width (perdicted):  1.2106651925
#  Minimum:  -1.4543768
#  Maximum:  4.8569307
# Variance:  1.0000000046889934
# Skewness:  1.5231293403577815
# Kurtosis:  3.781080963735363

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[20]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*280)
ax.fill_between(x,y*280,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Sr88",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -9.697247592077981e-10
# Standard Deviation:  0.999999999580113
# 25th Percentile (Perdicted):  -0.65828326
# 50th Percentile (Predicted, also the median):  -0.11284321
# 75th Percentile (perdicted):  0.7609058925000001
# Interquartile Width (perdicted):  1.4191891525
#  Minimum:  -2.155725
#  Maximum:  2.843146
# Variance:  0.9999999991602261
# Skewness:  0.17492150669544593
# Kurtosis:  -0.5552266008891613

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[21]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mo98",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  3.78591741977703e-09
# Standard Deviation:  0.9999999991858405
# 25th Percentile (Perdicted):  -0.71001516
# 50th Percentile (Predicted, also the median):  -0.19493921
# 75th Percentile (perdicted):  0.45161426250000003
# Interquartile Width (perdicted):  1.1616294225
#  Minimum:  -2.9463642
#  Maximum:  4.8598723
# Variance:  0.9999999983716811
# Skewness:  1.0740936772361191
# Kurtosis:  2.7324194548803042

# %%
ion = data[22]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cd111",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.05719202432672813
# Standard Deviation:  0.5369042517201622
# 25th Percentile (Perdicted):  -0.20326988
# 50th Percentile (Predicted, also the median):  -0.15159445
# 75th Percentile (perdicted):  -0.06228395
# Interquartile Width (perdicted):  0.14098592999999998
#  Minimum:  -0.31434458
#  Maximum:  6.6804085
# Variance:  0.28826617551518735
# Skewness:  10.190062767047685
# Kurtosis:  120.14780969808255

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.
