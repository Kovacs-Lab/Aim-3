# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data = np.genfromtxt('New_ionStats.csv',delimiter = ',')
data = pd.DataFrame(data)
plt.rcParams['figure.figsize'] = (20,10)

# %%
ion = data[2]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Li7",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.20334303
# Mean:  -0.2309820940979695
# Standard Deviation:  0.29442165637439777
# 25th Percentile (Perdicted):  -0.44744548
# 50th Percentile (Predicted, also the median):  -0.31137428
# 75th Percentile (perdicted):  -0.091049954
# Interquartile Width (perdicted):  0.356395526
#  Minimum:  -0.81049734
#  Maximum:  1.0
# Variance:  0.08668411174224394
# Skewness:  1.2287027250479186
# Kurtosis:  1.8711620455563542

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[3]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*150)
ax.fill_between(x,y*150,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("B11",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.0528921
# Mean:  0.00913241503652967
# Standard Deviation:  1.0068156204850551
# 25th Percentile (Perdicted):  -0.70195087
# 50th Percentile (Predicted, also the median):  -0.1504635
# 75th Percentile (perdicted):  0.603568365
# Interquartile Width (perdicted):  1.305519235
#  Minimum:  -2.0818458
#  Maximum:  3.4074562
# Variance:  1.0136776936527068
# Skewness:  0.7632991537019008
# Kurtosis:  0.2961097405601576

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[4]
print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*265)
ax.fill_between(x,y*265,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Na23",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# -0.32871976
# Mean:  -0.10562087670000002
# Standard Deviation:  0.2882863751172452
# 25th Percentile (Perdicted):  -0.26754734
# 50th Percentile (Predicted, also the median):  -0.10995043
# 75th Percentile (perdicted):  0.019662557
# Interquartile Width (perdicted):  0.28720989700000005
#  Minimum:  -0.5085364
#  Maximum:  3.0
# Variance:  0.083109034078241
# Skewness:  6.356993609094647
# Kurtosis:  68.16896664265097

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[5]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*175)
ax.fill_between(x,y*175,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mg26",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.018264839337899522
# Standard Deviation:  1.0336692896401534
# 25th Percentile (Perdicted):  -0.7050069999999999
# 50th Percentile (Predicted, also the median):  -0.14726049
# 75th Percentile (perdicted):  0.64729965
# Interquartile Width (perdicted):  1.35230665
#  Minimum:  -2.613343
#  Maximum:  4.0
# Variance:  1.0684722003451792
# Skewness:  0.8120664894781876
# Kurtosis:  0.9037597764209586

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[6]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Al27",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.21084928324467003
# Standard Deviation:  0.4496213747289688
# 25th Percentile (Perdicted):  -0.4178013
# 50th Percentile (Predicted, also the median):  -0.32585424
# 75th Percentile (perdicted):  -0.123872556
# Interquartile Width (perdicted):  0.293928744
#  Minimum:  -0.59944046
#  Maximum:  5.0
# Variance:  0.20215938061316777
# Skewness:  8.209452501157493
# Kurtosis:  92.25461558910989

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[7]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("P31",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.02739726222374433
# Standard Deviation:  1.0769384393478836
# 25th Percentile (Perdicted):  -0.64979695
# 50th Percentile (Predicted, also the median):  -0.09415333
# 75th Percentile (perdicted):  0.623637665
# Interquartile Width (perdicted):  1.273434615
#  Minimum:  -4.070458
#  Maximum:  6.0
# Variance:  1.1597964021450553
# Skewness:  0.9438359857615666
# Kurtosis:  4.731334040626317

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[8]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*240)
ax.fill_between(x,y*240,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("S34",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.03196347066986298
# Standard Deviation:  1.1041544900972888
# 25th Percentile (Perdicted):  -0.623184175
# 50th Percentile (Predicted, also the median):  -0.08385239
# 75th Percentile (perdicted):  0.500642495
# Interquartile Width (perdicted):  1.1238266700000001
#  Minimum:  -3.2634718
#  Maximum:  7.0
# Variance:  1.2191571380020039
# Skewness:  1.5498787339429203
# Kurtosis:  7.524301700010348

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[9]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*290)
ax.fill_between(x,y*290,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("K39",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.03652968428310503
# Standard Deviation:  1.1347468044201587
# 25th Percentile (Perdicted):  -0.68012365
# 50th Percentile (Predicted, also the median):  -0.17198473
# 75th Percentile (perdicted):  0.51397222
# Interquartile Width (perdicted):  1.19409587
#  Minimum:  -1.8564578
#  Maximum:  8.0
# Variance:  1.2876503101417618
# Skewness:  2.242250286750489
# Kurtosis:  10.89724662382881

# %% [markdown]
# This dataset exhibts slight skewness as well as kurtosis, in the same direction. In this case a transformation may be the most appropriate if any action is needed.

# %%
ion = data[10]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*210)
ax.fill_between(x,y*210,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ca44",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.041095888958904224
# Standard Deviation:  1.1684501926111335
# 25th Percentile (Perdicted):  -0.7186957599999999
# 50th Percentile (Predicted, also the median):  -0.06264514
# 75th Percentile (perdicted):  0.755839475
# Interquartile Width (perdicted):  1.4745352349999998
#  Minimum:  -2.4052176
#  Maximum:  9.0
# Variance:  1.3652758526129947
# Skewness:  2.108766116319603
# Kurtosis:  14.57113506765725

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[11]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*300)
ax.fill_between(x,y*300,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Fe54",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.18969580276868034
# Standard Deviation:  0.8015902505495428
# 25th Percentile (Perdicted):  -0.48911646
# 50th Percentile (Predicted, also the median):  -0.2964325
# 75th Percentile (perdicted):  -0.012269672
# Interquartile Width (perdicted):  0.47684678799999997
#  Minimum:  -1.3170694
#  Maximum:  10.0
# Variance:  0.6425469297760789
# Skewness:  10.577124554725447
# Kurtosis:  134.40486953752153

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[12]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*320)
ax.fill_between(x,y*320,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mn55",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.050228312404109444
# Standard Deviation:  1.2441560491628136
# 25th Percentile (Perdicted):  -0.710746135
# 50th Percentile (Predicted, also the median):  -0.29042685
# 75th Percentile (perdicted):  0.481822775
# Interquartile Width (perdicted):  1.1925689099999999
#  Minimum:  -1.37378
#  Maximum:  11.0
# Variance:  1.5479242746684214
# Skewness:  4.058972829329455
# Kurtosis:  28.44726497942559

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[13]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*380)
ax.fill_between(x,y*380,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Co59",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.05479452061963461
# Standard Deviation:  1.2856698971049123
# 25th Percentile (Perdicted):  -0.61203085
# 50th Percentile (Predicted, also the median):  -0.19777645
# 75th Percentile (perdicted):  0.27827415
# Interquartile Width (perdicted):  0.890305
#  Minimum:  -1.229277
#  Maximum:  12.0
# Variance:  1.6529470843217557
# Skewness:  4.950431329953991
# Kurtosis:  37.89595519065793

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[14]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*350)
ax.fill_between(x,y*350,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Ni60",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.05936072905433787
# Standard Deviation:  1.3293240124759182
# 25th Percentile (Perdicted):  -0.62110965
# 50th Percentile (Predicted, also the median):  -0.21005352
# 75th Percentile (perdicted):  0.35119535
# Interquartile Width (perdicted):  0.972305
#  Minimum:  -1.4204032
#  Maximum:  13.0
# Variance:  1.7671023301450755
# Skewness:  5.367185449898716
# Kurtosis:  44.08244973463368

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[15]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*360)
ax.fill_between(x,y*360,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cu63",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.06392693962328765
# Standard Deviation:  1.3749145474977962
# 25th Percentile (Perdicted):  -0.73013565
# 50th Percentile (Predicted, also the median):  -0.10035757
# 75th Percentile (perdicted):  0.67682783
# Interquartile Width (perdicted):  1.40696348
#  Minimum:  -4.3873267
#  Maximum:  14.0
# Variance:  1.8903900129210698
# Skewness:  4.841863730746649
# Kurtosis:  48.012593724526035

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[16]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Zn66",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.06849314604566216
# Standard Deviation:  1.4222552795272878
# 25th Percentile (Perdicted):  -0.65318782
# 50th Percentile (Predicted, also the median):  -0.27851564
# 75th Percentile (perdicted):  0.40705015
# Interquartile Width (perdicted):  1.06023797
#  Minimum:  -1.2560576
#  Maximum:  15.0
# Variance:  2.022810080143244
# Skewness:  6.065624177756928
# Kurtosis:  56.68233691464202

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[17]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*490)
ax.fill_between(x,y*490,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("As75",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.07305936038675782
# Standard Deviation:  1.4711772926369402
# 25th Percentile (Perdicted):  -0.5478203500000001
# 50th Percentile (Predicted, also the median):  -0.2891266
# 75th Percentile (perdicted):  0.1337182575
# Interquartile Width (perdicted):  0.6815386075000001
#  Minimum:  -1.0193691
#  Maximum:  16.0
# Variance:  2.1643626263705573
# Skewness:  6.702139253660438
# Kurtosis:  64.56578857874474

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.

# %%
ion = data[18]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*440)
ax.fill_between(x,y*440,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Se78",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.018822417802259912
# Standard Deviation:  1.2840071374863953
# 25th Percentile (Perdicted):  -0.07532722
# 50th Percentile (Predicted, also the median):  -0.07238038
# 75th Percentile (perdicted):  -0.06986687
# Interquartile Width (perdicted):  0.005460350000000003
#  Minimum:  -0.44698155
#  Maximum:  17.0
# Variance:  1.6486743291160069
# Skewness:  13.292317648756455
# Kurtosis:  176.79182322175282

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis. However, this dataset is borderline in this analysis.

# %%
ion = data[19]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*420)
ax.fill_between(x,y*420,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Rb85",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.08219177980639275
# Standard Deviation:  1.5731703352359534
# 25th Percentile (Perdicted):  -0.67767468
# 50th Percentile (Predicted, also the median):  -0.21449843
# 75th Percentile (perdicted):  0.5404655899999999
# Interquartile Width (perdicted):  1.21814027
#  Minimum:  -1.4543768
#  Maximum:  18.0
# Variance:  2.4748649036664023
# Skewness:  7.1656195813167
# Kurtosis:  77.33840089681382

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[20]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5)
ax.plot(x_all,y2*280)
ax.fill_between(x,y*280,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Sr88",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.0867579899022831
# Standard Deviation:  1.625981140681852
# 25th Percentile (Perdicted):  -0.65623472
# 50th Percentile (Predicted, also the median):  -0.10613473
# 75th Percentile (perdicted):  0.780419945
# Interquartile Width (perdicted):  1.436654665
#  Minimum:  -2.155725
#  Maximum:  19.0
# Variance:  2.643814669853057
# Skewness:  7.26536031804474
# Kurtosis:  83.62764400292576

# %% [markdown]
# The skewness and kurtosis of this data set would suggest that we can likely use normal based analysis without removal of outliers or transformation.

# %%
ion = data[21]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Mo98",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  0.09132420468187231
# Standard Deviation:  1.6798502492749752
# 25th Percentile (Perdicted):  -0.69617592
# 50th Percentile (Predicted, also the median):  -0.19194101
# 75th Percentile (perdicted):  0.46883838
# Interquartile Width (perdicted):  1.1650143
#  Minimum:  -2.9463642
#  Maximum:  20.0
# Variance:  2.8218968599891965
# Skewness:  7.873566522153465
# Kurtosis:  90.65812573669879

# %%
ion = data[22]
#print(ion[1]) #to double check what col you're on
mu = ion.mean()
sigma = ion.std()
x1 = ion.quantile(.25)
x2 = ion.quantile(.75)
x_all = np.arange(ion.min(), ion.max(), 0.001)

z1 = ( x1 - mu ) / sigma
z2 = ( x2 - mu ) / sigma
x = np.arange(z1, z2, 0.001)
y = stats.norm.pdf(x,0,1)
y2 = stats.norm.pdf(x_all,0,1)

fig ,ax = plt.subplots(figsize=(9,6))
ax.hist(ion,alpha = .5,bins = 50)
ax.plot(x_all,y2*130)
ax.fill_between(x,y*130,0, alpha=0.3, color='b')
ax.set_xlim([ion.min()-1,ion.max()+1])
ax.set_xlabel('# of Standard Deviations Outside the Mean')
ax.set_title("Cd111",fontsize = 24)
print("Mean: ",mu,"\nStandard Deviation: ",sigma,"\n25th Percentile (Perdicted): ",x1,
      "\n50th Percentile (Predicted, also the median): ",ion.quantile(.50),"\n75th Percentile (perdicted): ",x2,
     "\nInterquartile Width (perdicted): ",x2-x1,"\n Minimum: ",ion.min(),"\n Maximum: ",ion.max(),
     "\nVariance: ",ion.var(),"\nSkewness: ",ion.skew(),"\nKurtosis: ",ion.kurt())
# Out:
# Mean:  -0.038528124258375644
# Standard Deviation:  1.5089519410720074
# 25th Percentile (Perdicted):  -0.20995001
# 50th Percentile (Predicted, also the median):  -0.16016379
# 75th Percentile (perdicted):  -0.0929305
# Interquartile Width (perdicted):  0.11701951
#  Minimum:  -0.31434458
#  Maximum:  21.0
# Variance:  2.2769359604649786
# Skewness:  13.96902407666466
# Kurtosis:  195.74559814479616

# %% [markdown]
# They skewness and kurtosis of this data set would suggest that we use a non- normal based analysis, remove outliers, or transform the data to reduce skewness and kurtosis.
