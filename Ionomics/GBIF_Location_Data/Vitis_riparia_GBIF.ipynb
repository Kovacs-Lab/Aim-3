# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/Aim-3/Ionomics/GBIF Location Data'

# %%
data = pd.read_csv (r'/home/jovyan/Aim-3/Ionomics/GBIF Location Data/Vitis riparia.csv', sep='\t')
df = pd.DataFrame(data)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
df
# Out:
#          gbifID                            datasetKey  \
# 0    2574972750  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 1    2574971976  89c53edb-0fac-4118-bdc0-d70ca50953dc
# 2    2573129421  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 3    2573129169  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 4    2573127344  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 5    2573126507  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 6    2573115037  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 7    2573113404  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 8    2573112507  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 9    2573111950  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 10   2573110613  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 11   2573109762  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 12   2573108338  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 13   2573107916  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 14   2573107363  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 15   2573104904  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# ...
