# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/Aim-3/Ionomics/GBIF Location Data'

# %%
data = pd.read_csv (r'/home/jovyan/Aim-3/Ionomics/GBIF Location Data/Vitis labrusca.csv', sep='\t')
df = pd.DataFrame(data)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
df
# Out:
#          gbifID                            datasetKey  \
# 0    2573128636  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 1    2573126368  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 2    2573126211  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 3    2573125635  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 4    2573118946  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 5    2573118263  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 6    2573117773  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 7    2573116789  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 8    2573111949  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 9    2573111093  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 10   2573106302  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 11   2573104930  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 12   2573104861  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 13   2573103536  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 14   2573098991  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 15   2573098519  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# ...
