# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/Aim-3/Ionomics/GBIF Location Data'

# %%
data = pd.read_csv (r'/home/jovyan/Aim-3/Ionomics/GBIF Location Data/Vitis palmata.csv', sep='\t')
df = pd.DataFrame(data)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
df
# Out:
#         gbifID                            datasetKey  \
# 0   2446536380  7bd65a7a-f762-11e1-a439-00145eb45e9a
# 1   1949849184  d415c253-4d61-4459-9d25-4015b9084fb0
# 2   1949827212  d415c253-4d61-4459-9d25-4015b9084fb0
# 3   1702517245  af1b4db0-c8ce-4a95-b700-8a6a02bed9d6
# 4   1456214898  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 5   1456100980  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 6   1323870686  fce21d43-c0c7-4d1f-b6d2-fc048f053456
# 7   1321899178  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 8   1320730062  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 9   1320653853  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 10  1320502481  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 11  1319497760  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 12  1318609935  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 13  1318420439  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 14  1317665654  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 15  1317627882  821cc27a-e3bb-4bc5-ac34-89ada245069d
# 16  1317469382  821cc27a-e3bb-4bc5-ac34-89ada245069d
# ...
