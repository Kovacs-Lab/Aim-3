# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/home/jovyan/Aim-3/Ionomics/GBIF Location Data'

# %%
data = pd.read_csv (r'/home/jovyan/Aim-3/Ionomics/GBIF Location Data/Vitis aestivalis.csv', sep='\t')
df = pd.DataFrame(data)
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
df
# Out:
#          gbifID                            datasetKey  \
# 0    2573128356  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 1    2573122708  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 2    2573120194  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 3    2573119103  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 4    2573113036  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 5    2573109024  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 6    2573105866  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 7    2573105045  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 8    2573104736  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 9    2573102422  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 10   2573099331  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 11   2573098990  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 12   2573093147  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 13   2573092646  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 14   2573091906  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# 15   2573091706  e42c4be9-dc6d-466b-8df2-60ac8c47fadd
# ...
